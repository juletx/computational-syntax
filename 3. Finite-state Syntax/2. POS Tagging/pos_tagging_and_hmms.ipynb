# %% [markdown]
# # POS Tagging and HMMs

# %%
import nltk
nltk.download('brown')
nltk.download('universal_tagset')
from nltk.corpus import brown
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import numpy as np
import itertools
import pandas as pd
# Out:
# [nltk_data] Downloading package brown to /root/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# ## PART 1: TRIGRAM TAGGER WITH BACKOFF
#
# You will need to create train/dev/test splits for each domain in the brown corpus (be sure to use `tagset="universal"` when you call `brown.tagged_sents`). Afterwards, you will train a trigram tagger which backs off to a bigram tagger which backs off to a unigram tagger which finally backs off to a default tagger with `"NOUN"` (see NLTK book: Chapter 5.4 for details).
#
# For each domain test the tagger on the dev and test data.
#
# 1. Which domain has the best test accuracy? Which on has the worst? Why do you think this is the case?
#
# * `learned` (0.924234) and `belles_lettres` (0.923527) domains have the best test accuracy.
#
# * `humor` (0.835590) and `cience_fiction` (0.859890) domains have the worst test accuracy.
#
# * I think this is the case because there are more ambiguous contexts and unknown words in the test sets of some domains than on the other ones.
#
# 2. Which domain has the largest difference between dev and test? Why do you think this might be?
#
# * `humor` (0.038130) and `government` (0.017866) are the domains that have the largest positive difference between dev and test.
#
# * `science_fiction` (-0.041805) and `religion` (-0.028037) are the domains that have the largest negative difference between dev and test.
#
# * This might be related to the variability of the sentences found in each set. In some cases, the sentences from the dev set are more similar to the train sentences. In some other cases, the test set has more similarities with the train set. The sets that have the biggest positive and negative differences are the ones that have the worst test accuracy.

# %%
dev_accs = []
test_accs = []
diff_accs = []
for domain in brown.categories():
    # Create train/dev/test splits
    tagged_sents = brown.tagged_sents(categories=domain, tagset="universal")
    dev_idx = int(len(tagged_sents) * .7)
    test_idx = int(len(tagged_sents) * .8)
    train = tagged_sents[:dev_idx]
    dev = tagged_sents[dev_idx:test_idx]
    test = tagged_sents[test_idx:]

    # train the Ngram taggers
    t0 = nltk.DefaultTagger('NOUN')
    t1 = nltk.UnigramTagger(train, backoff=t0)
    t2 = nltk.BigramTagger(train, backoff=t1)
    t3 = nltk.TrigramTagger(train, backoff=t2)

    # get the dev and test accuracy and their difference
    dev_acc = t3.evaluate(dev)
    test_acc = t3.evaluate(test)
    dev_accs.append(dev_acc)
    test_accs.append(test_acc)
    diff_accs.append(dev_acc - test_acc)

    # print out the domain/dev acc/test acc/ and difference
    print("Domain: ", domain)
    print("Dev Acc: ", dev_acc)
    print("Test Acc: ", test_acc)
    print("Diff Acc: ", dev_acc - test_acc)
    print()
# Out:
# Domain:  adventure
# Dev Acc:  0.9113470640910836
# Test Acc:  0.9019279128248114
# Diff Acc:  0.00941915126627213
#
# Domain:  belles_lettres
# Dev Acc:  0.9271627073061407
# Test Acc:  0.9235269426517656
# Diff Acc:  0.0036357646543750954
#
# Domain:  editorial
# Dev Acc:  0.8966241560390098
# Test Acc:  0.8979980208571211
# Diff Acc:  -0.0013738648181113033
#
# Domain:  fiction
# Dev Acc:  0.9060704859493868
# Test Acc:  0.9108723958333333
# Diff Acc:  -0.004801909883946576
#
# Domain:  government
# Dev Acc:  0.9251101321585903
# Test Acc:  0.9072439400308253
# Diff Acc:  0.017866192127764968
#
# Domain:  hobbies
# Dev Acc:  0.8869329722410291
# Test Acc:  0.9008226161510833
# Diff Acc:  -0.013889643910054206
#
# Domain:  humor
# Dev Acc:  0.8737201365187713
# Test Acc:  0.8355899419729207
# Diff Acc:  0.03813019454585065
#
# Domain:  learned
# Dev Acc:  0.9143000753958281
# Test Acc:  0.9242341022824362
# Diff Acc:  -0.00993402688660805
#
# Domain:  lore
# Dev Acc:  0.9038090867370353
# Test Acc:  0.9144726083401472
# Diff Acc:  -0.010663521603111903
#
# Domain:  mystery
# Dev Acc:  0.9128591615638247
# Test Acc:  0.9118154572700027
# Diff Acc:  0.0010437042938220564
#
# Domain:  news
# Dev Acc:  0.9180925666199159
# Test Acc:  0.9037044173611446
# Diff Acc:  0.014388149258771299
#
# Domain:  religion
# Dev Acc:  0.8831328259268353
# Test Acc:  0.9111694152923538
# Diff Acc:  -0.02803658936551856
#
# Domain:  reviews
# Dev Acc:  0.8857011705301813
# Test Acc:  0.8725564864178725
# Diff Acc:  0.013144684112308735
#
# Domain:  romance
# Dev Acc:  0.9146670904179247
# Test Acc:  0.9137639001399219
# Diff Acc:  0.0009031902780027856
#
# Domain:  science_fiction
# Dev Acc:  0.8180851063829787
# Test Acc:  0.8598901098901099
# Diff Acc:  -0.04180500350713123

# %%
data = {"Domain": brown.categories(), "Dev Acc": dev_accs, "Test Acc": test_accs, "Diff Acc": diff_accs}
df = pd.DataFrame(data)
df
# Out:
#              Domain   Dev Acc  Test Acc  Diff Acc
# 0         adventure  0.911347  0.901928  0.009419
# 1    belles_lettres  0.927163  0.923527  0.003636
# 2         editorial  0.896624  0.897998 -0.001374
# 3           fiction  0.906070  0.910872 -0.004802
# 4        government  0.925110  0.907244  0.017866
# 5           hobbies  0.886933  0.900823 -0.013890
# 6             humor  0.873720  0.835590  0.038130
# 7           learned  0.914300  0.924234 -0.009934
# 8              lore  0.903809  0.914473 -0.010664
# 9           mystery  0.912859  0.911815  0.001044
# 10             news  0.918093  0.903704  0.014388
# 11         religion  0.883133  0.911169 -0.028037
# 12          reviews  0.885701  0.872556  0.013145
# 13          romance  0.914667  0.913764  0.000903
# 14  science_fiction  0.818085  0.859890 -0.041805

# %%
df.sort_values(by=['Test Acc'], ascending=False, inplace=True)
df
# Out:
#              Domain   Dev Acc  Test Acc  Diff Acc
# 7           learned  0.914300  0.924234 -0.009934
# 1    belles_lettres  0.927163  0.923527  0.003636
# 8              lore  0.903809  0.914473 -0.010664
# 13          romance  0.914667  0.913764  0.000903
# 9           mystery  0.912859  0.911815  0.001044
# 11         religion  0.883133  0.911169 -0.028037
# 3           fiction  0.906070  0.910872 -0.004802
# 4        government  0.925110  0.907244  0.017866
# 10             news  0.918093  0.903704  0.014388
# 0         adventure  0.911347  0.901928  0.009419
# 5           hobbies  0.886933  0.900823 -0.013890
# 2         editorial  0.896624  0.897998 -0.001374
# 12          reviews  0.885701  0.872556  0.013145
# 14  science_fiction  0.818085  0.859890 -0.041805
# 6             humor  0.873720  0.835590  0.038130

# %%
df.plot(x="Domain", y=["Test Acc", "Dev Acc"], kind="bar", figsize=(10, 5), title="Test and Dev accuracies ordered by Test accuracy")

# %%
df.sort_values(by=['Dev Acc'], ascending=False, inplace=True)
df
# Out:
#              Domain   Dev Acc  Test Acc  Diff Acc
# 1    belles_lettres  0.927163  0.923527  0.003636
# 4        government  0.925110  0.907244  0.017866
# 10             news  0.918093  0.903704  0.014388
# 13          romance  0.914667  0.913764  0.000903
# 7           learned  0.914300  0.924234 -0.009934
# 9           mystery  0.912859  0.911815  0.001044
# 0         adventure  0.911347  0.901928  0.009419
# 3           fiction  0.906070  0.910872 -0.004802
# 8              lore  0.903809  0.914473 -0.010664
# 2         editorial  0.896624  0.897998 -0.001374
# 5           hobbies  0.886933  0.900823 -0.013890
# 12          reviews  0.885701  0.872556  0.013145
# 11         religion  0.883133  0.911169 -0.028037
# 6             humor  0.873720  0.835590  0.038130
# 14  science_fiction  0.818085  0.859890 -0.041805

# %%
df.plot(x="Domain", y=["Test Acc", "Dev Acc"], kind="bar", figsize=(10, 5), title="Test and Dev accuracies ordered by Dev accuracy")

# %%
df.sort_values(by=['Diff Acc'], ascending=False, inplace=True)
df
# Out:
#              Domain   Dev Acc  Test Acc  Diff Acc
# 6             humor  0.873720  0.835590  0.038130
# 4        government  0.925110  0.907244  0.017866
# 10             news  0.918093  0.903704  0.014388
# 12          reviews  0.885701  0.872556  0.013145
# 0         adventure  0.911347  0.901928  0.009419
# 1    belles_lettres  0.927163  0.923527  0.003636
# 9           mystery  0.912859  0.911815  0.001044
# 13          romance  0.914667  0.913764  0.000903
# 2         editorial  0.896624  0.897998 -0.001374
# 3           fiction  0.906070  0.910872 -0.004802
# 7           learned  0.914300  0.924234 -0.009934
# 8              lore  0.903809  0.914473 -0.010664
# 5           hobbies  0.886933  0.900823 -0.013890
# 11         religion  0.883133  0.911169 -0.028037
# 14  science_fiction  0.818085  0.859890 -0.041805

# %%
df.plot(x="Domain", y=["Diff Acc"], kind="bar", figsize=(10, 5), title="Dev - Test accuracy differences ordered")

# %% [markdown]
# ## PART 2: CONFUSION MATRIX
#
# Next, you will use the trigram tagger you trained for the final domain and collect the predictions on the test set using `tagger.tag_sents()`. Note that the tagger expects UNTAGGED sentences, so you will need to remove the tags from the test set. Now you will create a confusion matrix using the code from `sklearn.metrics.confusion_matrix`.
#
# This function takes two arguments: 1) the true labels and 2) the predicted labels. Note that these should be flat lists containing only the tags, i.e., `test_labels = ['ADP', 'DET', 'NOUN',…]`. Therefore, you will need to manipulate both the test and predictions to get them into the correct format. Finally, use `plot_confusion_matrix()` to plot the errors.
#
#
# 1. Which labels are most often predicted correctly? Why do you think this could be?
#
# * `CONJ`, `DET`, `NOUN`, `PRON` are predicted correctly most of the times.
#
# * `CONJ`, `DET`, and `PRON` are closed class categories and therefore it is easier to predict them. As there are less words, finding an unkown word is more difficult. `NOUN` is the default tag and the unkown nouns are always tagged correcly.
#
# 2. What are the most common errors? Why do you think this is?
#
# * Tagging `ADJ`, `ADV` and `VERB` as `NOUN` is the most common mistake.
#
# * This is related to `NOUN` being the default tag. All the unkown words of thos categories will be tagged as `NOUN`. As they are open class, it is expected that there are many unkown words.

# %%
def plot_confusion_matrix(cm, labels, cmap=plt.cm.BuPu):
    """
    This function plots the confusion matrix.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    x_tick_marks = np.arange(len(labels))
    y_tick_marks = np.arange(len(labels))
    plt.xticks(x_tick_marks, labels, rotation=45)
    plt.yticks(y_tick_marks, labels)
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, "{}".format(cm[i, j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()
    
# convert test to the correct data format (a flat list of tags)
test_tags = [tag for sent in test for (word, tag) in sent]

# remove the tags from the original test data and use tag_sents() to get the predictions from the final model
sents = brown.sents(categories=domain)
test_idx = int(len(sents) * .8)
test_sents = sents[test_idx:]
pred_sents = t3.tag_sents(test_sents)

# convert the predictions to the correct data format (a flat list of predicted tags)
pred_tags = [tag for sent in pred_sents for (word, tag) in sent]

# get a set of the labels (sorted(set(test)))
labels = sorted(set(test_tags))

# create the confusion matrix and plot it using the plot_confusion_matrix function
cm = confusion_matrix(test_tags, pred_tags)
plot_confusion_matrix(cm, labels)

# %% [markdown]
# ## PART 3: VITERBI OR ERROR ANALYSIS
#
# In this section, you will need to choose ONE of the following: a) implementing viterbi in a simple HMM-based tagger or performing in-depth error analysis on the previous results.
#
# a) Complete the code in simple_hmm.py
#
# b) Error analysis:
#
# 1. Based on the code already available in pos_exercise.py, create a function to find sentences with errors. Use this function to collect all the sentences with errors in the dev set of the science_fiction domain of the brown corpus.
#
# 2. Now, you will need to categorize what type of errors are found. You can use the following information to help you:
#     - a) whether the word is found in the training set or not
#     - b) the relative frequency of the word in the training set
#     - c) the number of tags associated with the word in train
#     - etc.
# 3. Hypothesize what phenomena might be difficult for the tagger.

# %% [markdown]
# ### VITERBI

# %%
class HMM:
    """
    Q = a set of N hidden states
    A = a transition probability matrix where each a_i_j represents the probability of moving from state i to state j and np.sum(A) == 1
    O = a sequence of T observations from V
    V = a vocabulary of seen observations
    B = a sequence of emission probabilities expressing the probability of an observation o_t being generated from a state i
    PI = an initial probability distribution over states
    """

    def __init__(self, Q, V):

        self.Q = Q
        self.V = V

        # Q x Q matrix
        self.A = np.random.random((len(Q), len(Q)))
        # make sure all rows sum to 1
        self.A /= self.A.sum(1)

        # Emission probability matrix, Q x V
        self.B = np.random.random((len(V), len(Q)))
        self.B /= self.B.sum(0)

        # initial probability distribution over states, Q vector
        self.PI = np.random.random((len(Q)))

    def viterbi(self, O):
        """
        O = sequence of T observations
        This code should return an array backpointer with the
        most likely sequence through the trellis.

        e.g. O = [3, 1]
             backpointer = [0, 1]

        """

        # Set up trellis = Q x T matrix
        trellis = np.zeros((len(self.Q), len(O)))

        # set up backpointer
        backpointer = np.zeros(len(O), dtype="int")

        # compute the emission probabilaties for each beginning state
        trellis[0][0] = self.PI[0] * self.B[O[0]-1][0]
        trellis[1][0] = self.PI[1] * self.B[O[0]-1][1]
        backpointer[0] = trellis[:, 0].argmax()

        # compute forward probabilities keeping track of argmaxes with backpointer

        for t in range(1, len(O)):
            trellis[0][t] = max(trellis[:, t-1]) * self.A[backpointer[t-1]][0] * self.B[O[t]-1][0]
            trellis[1][t] = max(trellis[:, t-1]) * self.A[backpointer[t-1]][1] * self.B[O[t]-1][1]
            backpointer[t] = trellis[:, t].argmax()

        return backpointer


def main():

    """
    The example is taken from Jurafsky and Martin Ch. 8.4.

    This HMM predicts whether the day was hot or cold,
    depending on the number of icecreams that the
    author ate that day (1, 2, or 3).
    """
    label_map = {0: "hot", 1: "cold"}

    hmm = HMM(Q=["hot", "cold"], V=[1, 2, 3])

    # We set the values to those in Jurafsky and Martin
    hmm.A = np.array([[0.6, 0.4],
                      [0.5, 0.5]])

    hmm.B = np.array([[0.2, 0.5],
                      [0.4, 0.4],
                      [0.4, 0.1]])

    hmm.PI = np.array([.8, .2])

    # The observed sequence of icecream eaten we want to predict
    O = [3, 1, 3, 2, 2, 2, 2]

    labels = hmm.viterbi(O)

    print([label_map[l] for l in labels])


if __name__ == "__main__":
    main()
# Out:
# ['hot', 'cold', 'hot', 'hot', 'hot', 'hot', 'hot']

# %% [markdown]
# ### ERROR ANALYSIS

# %%
sents = brown.sents(categories=domain)
dev_idx = int(len(sents) * .7)
test_idx = int(len(sents) * .8)
dev_sents = sents[dev_idx:test_idx]
pred_dev = t3.tag_sents(dev_sents)

for i in range(len(dev)):
    mistakes = 0
    for j in range(len(dev[i])):
        if dev[i][j] != pred_dev[i][j]:
            if mistakes == 0:
                print("Sentence", str(i) + ":", " ".join(dev_sents[i]))
            print("Mistake", str(mistakes) + ":", dev[i][j][0], dev[i][j][1], pred_dev[i][j][1])
            mistakes += 1
    if mistakes != 0:
        print()
# Out:
# Sentence 0: `` Don't try anything violent , Stormy .
# Mistake 0: try VERB NOUN
#
# Sentence 1: I outweigh you fifty pounds and I'm fast for a big man '' .
# Mistake 0: outweigh VERB NOUN
# Mistake 1: fifty NUM NOUN
# Mistake 2: fast ADV ADJ
#
# Sentence 2: `` I wasn't planning on jumping you .
# Mistake 0: planning VERB NOUN
# Mistake 1: jumping VERB NOUN
#
# Sentence 3: Why do you have to jump me the first time something goes wrong ? ?
# Mistake 0: jump VERB NOUN
#
# Sentence 4: She lived and was given a name .
# Mistake 0: lived VERB NOUN
#
# Sentence 6: For her first three vegetable months she waved her crabbed claws , kicked weakly with her clubbed feet and enjoyed the usual routine of the infant .
# Mistake 0: waved VERB NOUN
# Mistake 1: crabbed ADJ NOUN
# Mistake 2: kicked VERB NOUN
# Mistake 3: weakly ADV NOUN
# Mistake 4: her PRON DET
# Mistake 5: clubbed VERB NOUN
# Mistake 6: enjoyed VERB NOUN
# Mistake 7: usual ADJ NOUN
#
# Sentence 7: She was not alone for there were three other such children in the big city's special nursery .
# Mistake 0: special ADJ NOUN
#
# Sentence 8: Soon they all were removed to Central Laboratory School where their delicate transformation began .
# Mistake 0: Soon ADV NOUN
# Mistake 1: removed VERB NOUN
# Mistake 2: to ADP PRT
# Mistake 3: Central ADJ NOUN
# Mistake 4: delicate ADJ NOUN
#
# Sentence 9: One of the babies died in the initial transferral but of Helva's `` class '' , seventeen thrived in the metal shells .
# Mistake 0: initial ADJ NOUN
# Mistake 1: seventeen NUM NOUN
# Mistake 2: thrived VERB NOUN
#
# Sentence 10: Instead of kicking feet , Helva's neural responses started her wheels ; ;
# Mistake 0: kicking VERB NOUN
# Mistake 1: neural ADJ NOUN
# Mistake 2: her DET PRON
#
# Sentence 11: instead of grabbing with hands , she manipulated mechanical extensions .
# Mistake 0: grabbing VERB NOUN
# Mistake 1: manipulated VERB NOUN
# Mistake 2: mechanical ADJ NOUN
#
# Sentence 12: As she matured , more and more neural synapses would be adjusted to operate other mechanisms that went into the maintenance and running of a space ship .
# Mistake 0: matured VERB NOUN
# Mistake 1: more ADJ ADV
# Mistake 2: neural ADJ NOUN
# Mistake 3: adjusted VERB NOUN
# Mistake 4: operate VERB NOUN
# Mistake 5: running NOUN VERB
#
# Sentence 13: For Helva was destined to be the `` brain '' half of a scout ship , partnered with a man or a woman , whichever she chose , as the mobile half .
# Mistake 0: destined VERB NOUN
# Mistake 1: partnered VERB NOUN
# Mistake 2: whichever DET NOUN
# Mistake 3: chose VERB NOUN
# Mistake 4: mobile ADJ NOUN
# Mistake 5: half PRT ADV
#
# Sentence 15: Her initial intelligence tests registered above normal and her adaptation index was unusually high .
# Mistake 0: initial ADJ NOUN
# Mistake 1: registered VERB NOUN
# Mistake 2: unusually ADV NOUN
#
# Sentence 16: As long as her development within her shell lived up to expectations , and there were no side-effects from the pituitary tinkering , Helva would live a rewarding , rich and unusual life , a far cry from what she would have faced as an ordinary , `` normal '' being .
# Mistake 0: As ADV ADP
# Mistake 1: within ADP NOUN
# Mistake 2: lived VERB NOUN
# Mistake 3: to ADP PRT
# Mistake 4: rewarding ADJ NOUN
# Mistake 5: rich ADJ NOUN
# Mistake 6: unusual ADJ NOUN
# Mistake 7: far ADJ NOUN
# Mistake 8: ordinary ADJ NOUN
# Mistake 9: being NOUN VERB
#
# Sentence 17: However , no diagram of her brain patterns , no early I.Q. tests recorded certain essential facts about Helva that Central must eventually learn .
# Mistake 0: early ADJ NOUN
# Mistake 1: recorded VERB NOUN
# Mistake 2: essential ADJ NOUN
# Mistake 3: Central ADJ NOUN
# Mistake 4: learn VERB NOUN
#
# Sentence 18: They would have to bide their official time and see , trusting that the massive doses of shell-psychology would suffice her , too , as the necessary bulwark against her unusual confinement and the pressures of her profession .
# Mistake 0: bide VERB NOUN
# Mistake 1: official ADJ NOUN
# Mistake 2: trusting VERB NOUN
# Mistake 3: massive ADJ NOUN
# Mistake 4: suffice VERB NOUN
# Mistake 5: her PRON DET
# Mistake 6: necessary ADJ NOUN
# Mistake 7: unusual ADJ NOUN
#
# Sentence 19: A ship run by a human brain could not run rogue or insane with the power and resources Central had to build into their scout ships .
# Mistake 0: insane ADJ NOUN
# Mistake 1: Central ADJ NOUN
#
# Sentence 20: Brain ships were , of course , long past the experimental stages .
# Mistake 0: past ADP NOUN
# Mistake 1: experimental ADJ NOUN
#
# Sentence 21: Most babes survived the techniques of pituitary manipulation that kept their bodies small , eliminating the necessity of transfers from smaller to larger shells .
# Mistake 0: Most ADJ NOUN
# Mistake 1: that PRON ADP
# Mistake 2: eliminating VERB NOUN
# Mistake 3: to ADP PRT
# Mistake 4: larger ADJ NOUN
#
# Sentence 22: And very , very few were lost when the final connection was made to the control panels of ship or industrial combine .
# Mistake 0: to ADP PRT
# Mistake 1: industrial ADJ NOUN
#
# Sentence 23: Shell people resembled mature dwarfs in size whatever their natal deformities were , but the well-oriented brain would not have changed places with the most perfect body in the Universe .
# Mistake 0: resembled VERB NOUN
# Mistake 1: mature ADJ NOUN
# Mistake 2: natal ADJ NOUN
# Mistake 3: well-oriented ADJ NOUN
#
# Sentence 24: So , for happy years , Helva scooted around in her shell with her classmates , playing such games as Stall , Power-Seek , studying her lessons in trajectory , propulsion techniques , computation , logistics , mental hygiene , basic alien psychology , philology , space history , law , traffic , codes : all the et ceteras that eventually became compounded into a reasoning , logical , informed citizen .
# Mistake 0: scooted VERB NOUN
# Mistake 1: around ADV ADP
# Mistake 2: playing VERB NOUN
# Mistake 3: studying VERB NOUN
# Mistake 4: alien NOUN ADJ
# Mistake 5: et X NOUN
# Mistake 6: ceteras X NOUN
# Mistake 7: that PRON ADP
# Mistake 8: became VERB NOUN
# Mistake 9: compounded VERB NOUN
# Mistake 10: reasoning VERB NOUN
#
# Sentence 25: Not so obvious to her , but of more importance to her teachers , Helva ingested the precepts of her conditioning as easily as she absorbed her nutrient fluid .
# Mistake 0: Not ADV NOUN
# Mistake 1: obvious ADJ NOUN
# Mistake 2: her PRON DET
# Mistake 3: more ADJ ADV
# Mistake 4: ingested VERB NOUN
# Mistake 5: as ADV ADP
# Mistake 6: easily ADV NOUN
# Mistake 7: absorbed VERB NOUN
# Mistake 8: nutrient ADJ NOUN
#
# Sentence 26: She would one day be grateful to the patient drone of the sub-conscious-level instruction .
# Mistake 0: grateful ADJ NOUN
# Mistake 1: to ADP PRT
# Mistake 2: patient ADJ NOUN
#
# Sentence 27: Helva's civilization was not without busy , do-good associations , exploring possible inhumanities to terrestrial as well as extraterrestrial citizens .
# Mistake 0: do-good ADJ NOUN
# Mistake 1: exploring VERB NOUN
# Mistake 2: to ADP PRT
# Mistake 3: terrestrial ADJ NOUN
# Mistake 4: as ADV ADP
# Mistake 5: as ADP ADV
# Mistake 6: extraterrestrial ADJ NOUN
#
# Sentence 28: One such group got all incensed over shelled `` children '' when Helva was just turning fourteen .
# Mistake 0: all ADV PRT
# Mistake 1: incensed VERB NOUN
# Mistake 2: shelled VERB NOUN
# Mistake 3: turning VERB NOUN
# Mistake 4: fourteen NUM NOUN
#
# Sentence 29: When they were forced to , Central Worlds shrugged its shoulders , arranged a tour of the Laboratory Schools and set the tour off to a big start by showing the members case histories , complete with photographs .
# Mistake 0: to ADP PRT
# Mistake 1: Central ADJ NOUN
# Mistake 2: shrugged VERB NOUN
# Mistake 3: arranged VERB NOUN
# Mistake 4: to ADP PRT
# Mistake 5: start NOUN VERB
# Mistake 6: showing VERB NOUN
# Mistake 7: case VERB NOUN
#
# Sentence 30: Very few committees ever looked past the first few photos .
# Mistake 0: Very ADV NOUN
# Mistake 1: past ADP NOUN
#
# Sentence 31: Most of their original objections about `` shells '' were overridden by the relief that these hideous ( to them ) bodies were mercifully concealed .
# Mistake 0: Most ADJ NOUN
# Mistake 1: overridden VERB NOUN
# Mistake 2: hideous ADJ NOUN
# Mistake 3: mercifully ADV NOUN
# Mistake 4: concealed VERB NOUN
#
# Sentence 32: Helva's class was doing Fine Arts , a selective subject in her crowded program .
# Mistake 0: Fine ADJ ADV
# Mistake 1: selective ADJ NOUN
# Mistake 2: crowded VERB NOUN
#
# Sentence 33: She had activated one of her microscopic tools which she would later use for minute repairs to various parts of her control panel .
# Mistake 0: activated VERB NOUN
# Mistake 1: microscopic ADJ NOUN
# Mistake 2: minute ADJ NOUN
# Mistake 3: to ADP PRT
# Mistake 4: various ADJ NOUN
#
# Sentence 34: Her subject was large -- a copy of the Last Supper -- and her canvas , small -- the head of a tiny screw .
# Mistake 0: large ADJ NOUN
# Mistake 1: Last ADJ NOUN
#
# Sentence 35: She had tuned her sight to the proper degree .
# Mistake 0: tuned VERB NOUN
#
# Sentence 36: As she worked she absentmindedly crooned , producing a curious sound .
# Mistake 0: absentmindedly ADV NOUN
# Mistake 1: crooned VERB NOUN
# Mistake 2: producing VERB NOUN
# Mistake 3: curious ADJ NOUN
#
# Sentence 37: Shell people used their own vocal cords and diaphragms but sound issued through microphones rather than mouths .
# Mistake 0: vocal ADJ NOUN
# Mistake 1: issued VERB NOUN
# Mistake 2: rather ADP NOUN
#
# Sentence 38: Helva's hum then had a curious vibrancy , a warm , dulcet quality even in its aimless chromatic wanderings .
# Mistake 0: curious ADJ NOUN
# Mistake 1: dulcet ADJ NOUN
# Mistake 2: in ADP PRT
# Mistake 3: aimless ADJ NOUN
# Mistake 4: chromatic ADJ NOUN
#
# Sentence 39: `` Why , what a lovely voice you have '' , said one of the female visitors .
# Mistake 0: lovely ADJ NOUN
#
# Sentence 40: Helva `` looked '' up and caught a fascinating panorama of regular , dirty craters on a flaky pink surface .
# Mistake 0: caught VERB NOUN
# Mistake 1: fascinating ADJ NOUN
# Mistake 2: regular ADJ NOUN
# Mistake 3: dirty ADJ NOUN
# Mistake 4: flaky ADJ NOUN
#
# Sentence 41: Her hum became a gurgle of surprise .
# Mistake 0: became VERB NOUN
#
# Sentence 42: She instinctively regulated her `` sight '' until the skin lost its cratered look and the pores assumed normal proportions .
# Mistake 0: instinctively ADV NOUN
# Mistake 1: regulated VERB NOUN
# Mistake 2: cratered VERB NOUN
# Mistake 3: assumed VERB NOUN
#
# Sentence 43: `` Yes , we have quite a few years of voice training , madam '' , remarked Helva calmly .
# Mistake 0: quite PRT NOUN
# Mistake 1: remarked VERB NOUN
# Mistake 2: calmly ADV NOUN
#
# Sentence 44: `` Vocal peculiarities often become excessively irritating during prolonged intra-stellar distances and must be eliminated .
# Mistake 0: Vocal ADJ NOUN
# Mistake 1: excessively ADV NOUN
# Mistake 2: irritating ADJ NOUN
# Mistake 3: prolonged VERB NOUN
# Mistake 4: intra-stellar ADJ NOUN
# Mistake 5: eliminated VERB NOUN
#
# Sentence 45: I enjoyed my lessons '' .
# Mistake 0: enjoyed VERB NOUN
#
# Sentence 46: Although this was the first time that Helva had seen unshelled people , she took this experience calmly .
# Mistake 0: Although ADP NOUN
# Mistake 1: unshelled ADJ NOUN
# Mistake 2: calmly ADV NOUN
#
# Sentence 47: Any other reaction would have been reported instantly .
# Mistake 0: instantly ADV NOUN
#
# Sentence 48: `` I meant that you have a nice singing voice dear '' , the lady amended .
# Mistake 0: nice ADJ NOUN
# Mistake 1: singing VERB NOUN
# Mistake 2: dear NOUN PRT
# Mistake 3: amended VERB NOUN
#
# Sentence 49: `` Thank you .
# Mistake 0: Thank VERB NOUN
#
# Sentence 50: Would you like to see my work '' ? ?
# Mistake 0: Would VERB NOUN
# Mistake 1: like VERB ADP
# Mistake 2: to PRT ADP
#
# Sentence 51: Helva asked , politely .
# Mistake 0: politely ADV NOUN
#
# Sentence 52: She instinctively sheered away from personal discussions but she filed the comment away for further meditation .
# Mistake 0: instinctively ADV NOUN
# Mistake 1: sheered VERB NOUN
# Mistake 2: personal ADJ NOUN
# Mistake 3: filed VERB NOUN
# Mistake 4: further ADJ NOUN
#
# Sentence 54: Asked the lady .
# Mistake 0: Asked VERB NOUN
#
# Sentence 55: `` I am currently reproducing the Last Supper on the head of a screw '' .
# Mistake 0: currently ADV NOUN
# Mistake 1: reproducing VERB NOUN
# Mistake 2: Last ADJ NOUN
#
# Sentence 56: `` No , I say '' , the lady twittered .
# Mistake 0: No ADV DET
# Mistake 1: twittered VERB NOUN
#
# Sentence 57: Helva turned her vision back to magnification and surveyed her copy critically .
# Mistake 0: her DET PRON
# Mistake 1: to ADP PRT
# Mistake 2: surveyed VERB NOUN
# Mistake 3: critically ADV NOUN
#
# Sentence 58: `` Of course , some of my color values do not match the old Master's and the perspective is faulty but I believe it to be a fair copy '' .
# Mistake 0: faulty ADJ NOUN
#
# Sentence 59: The lady's eyes , unmagnified , bugged out .
# Mistake 0: unmagnified ADJ NOUN
# Mistake 1: bugged VERB NOUN
#
# Sentence 60: `` Oh , I forget '' , and Helva's voice was really contrite .
# Mistake 0: contrite ADJ NOUN
#
# Sentence 61: If she could have blushed , she would have .
# Mistake 0: blushed VERB NOUN
#
# Sentence 62: `` You people don't have adjustable vision '' .
# Mistake 0: people VERB NOUN
# Mistake 1: adjustable ADJ NOUN
#
# Sentence 63: The monitor of this discourse grinned with pride and amusement as Helva's tone indicated pity for the unfortunate .
# Mistake 0: grinned VERB NOUN
# Mistake 1: indicated VERB NOUN
#
# Sentence 64: `` Here , this will help '' , suggested Helva , substituting a magnifying device in one extension and holding it over the picture .
# Mistake 0: will NOUN VERB
# Mistake 1: substituting VERB NOUN
# Mistake 2: magnifying VERB NOUN
# Mistake 3: over ADP PRT
#
# Sentence 65: In a kind of shock , the ladies and gentlemen of the committee bent to observe the incredibly copied and brilliantly executed Last Supper on the head of a screw .
# Mistake 0: bent VERB NOUN
# Mistake 1: observe VERB NOUN
# Mistake 2: incredibly ADV NOUN
# Mistake 3: copied VERB NOUN
# Mistake 4: brilliantly ADV NOUN
# Mistake 5: executed VERB NOUN
# Mistake 6: Last ADJ NOUN
#
# Sentence 66: `` Well '' , remarked one gentleman who had been forced to accompany his wife , `` the good Lord can eat where angels fear to tread '' .
# Mistake 0: remarked VERB NOUN
# Mistake 1: accompany VERB NOUN
# Mistake 2: fear VERB NOUN
# Mistake 3: tread VERB NOUN
#
# Sentence 67: `` Are you referring , sir '' , asked Helva politely , `` to the Dark Age discussions of the number of angels who could stand on the head of a pin '' ? ?
# Mistake 0: referring VERB NOUN
# Mistake 1: politely ADV NOUN
# Mistake 2: to ADP PRT
# Mistake 3: Dark ADJ NOUN
#
# Sentence 68: `` I had that in mind '' .
# Mistake 0: that DET ADP
#
# Sentence 69: `` If you substitute ' atom ' for ' angel ' , the problem is not insoluble , given the metallic content of the pin in question '' .
# Mistake 0: substitute VERB NOUN
# Mistake 1: insoluble ADJ NOUN
# Mistake 2: metallic ADJ NOUN
# Mistake 3: content NOUN ADJ
#
# Sentence 70: `` Which you are programed to compute '' ? ?
# Mistake 0: Which DET NOUN
# Mistake 1: programed VERB NOUN
# Mistake 2: compute VERB NOUN
#
# Sentence 72: `` Did they remember to program a sense of humor , as well , young lady '' ? ?
# Mistake 0: remember VERB NOUN
# Mistake 1: program VERB NOUN
# Mistake 2: as ADV ADP
#
# Sentence 73: `` We are directed to develop a sense of proportion , sir , which contributes the same effect '' .
# Mistake 0: directed VERB NOUN
# Mistake 1: contributes VERB NOUN
#
# Sentence 74: The good man chortled appreciatively and decided the trip was worth his time .
# Mistake 0: chortled VERB NOUN
# Mistake 1: appreciatively ADV NOUN
#
# Sentence 75: If the investigation committee spent months digesting the thoughtful food served them at the Laboratory School , they left Helva with a morsel as well .
# Mistake 0: digesting VERB NOUN
# Mistake 1: thoughtful ADJ NOUN
# Mistake 2: served VERB NOUN
# Mistake 3: as ADV ADP
#
# Sentence 76: `` Singing '' as applicable to herself required research .
# Mistake 0: Singing VERB NOUN
# Mistake 1: as ADV ADP
# Mistake 2: to ADP PRT
# Mistake 3: herself PRON NOUN
#
# Sentence 77: She had , of course , been exposed to and enjoyed a music appreciation course which had included the better known classical works such as `` Tristan und Isolde '' , `` Candide '' , `` Oklahoma '' , `` Nozze de Figaro '' , the atomic age singers , Eileen Farrell , Elvis Presley and Geraldine Todd , as well as the curious rhythmic progressions of the Venusians , Capellan visual chromatics and the sonic concerti of the Altairians .
# Mistake 0: exposed VERB NOUN
# Mistake 1: to ADP PRT
# Mistake 2: enjoyed VERB NOUN
# Mistake 3: included VERB NOUN
# Mistake 4: classical ADJ NOUN
# Mistake 5: works NOUN VERB
# Mistake 6: und X NOUN
# Mistake 7: Nozze X NOUN
# Mistake 8: de X NOUN
# Mistake 9: as ADV ADP
# Mistake 10: as ADP ADV
# Mistake 11: curious ADJ NOUN
# Mistake 12: rhythmic ADJ NOUN
# Mistake 13: Capellan ADJ NOUN
# Mistake 14: visual ADJ NOUN
# Mistake 15: sonic ADJ NOUN
#
# Sentence 78: But `` singing '' for any shell person posed considerable technical difficulties to be overcome .
# Mistake 0: singing VERB NOUN
# Mistake 1: posed VERB NOUN
# Mistake 2: considerable ADJ NOUN
# Mistake 3: technical ADJ NOUN
# Mistake 4: overcome VERB NOUN
#
# Sentence 79: Shell people were schooled to examine every aspect of a problem or situation before making a prognosis .
# Mistake 0: schooled VERB NOUN
# Mistake 1: examine VERB NOUN
#
# Sentence 80: Balanced properly between optimism and practicality , the nondefeatist attitude of the shell people led them to extricate themselves , their ships and personnel , from bizarre situations .
# Mistake 0: Balanced VERB NOUN
# Mistake 1: properly ADV NOUN
# Mistake 2: led VERB NOUN
# Mistake 3: extricate VERB NOUN
# Mistake 4: themselves PRON NOUN
#
# Sentence 81: Therefore to Helva , the problem that she couldn't open her mouth to sing , among other restrictions , did not bother her .
# Mistake 0: to ADP PRT
# Mistake 1: open VERB ADV
# Mistake 2: to PRT ADP
# Mistake 3: sing VERB NOUN
#
# Sentence 82: She would work out a method , by-passing her limitations , whereby she could sing .
# Mistake 0: by-passing ADJ NOUN
# Mistake 1: whereby ADV NOUN
# Mistake 2: sing VERB NOUN
#
# Sentence 83: She approached the problem by investigating the methods of sound reproduction through the centuries , human and instrumental .
# Mistake 0: approached VERB NOUN
# Mistake 1: investigating VERB NOUN
# Mistake 2: instrumental ADJ NOUN
#
# Sentence 84: Her own sound production equipment was essentially more instrumental than vocal .
# Mistake 0: essentially ADV NOUN
# Mistake 1: instrumental ADJ NOUN
# Mistake 2: vocal ADJ NOUN
#
# Sentence 85: Breath control and the proper enunciation of vowel sounds within the oral cavity appeared to require the most development and practice .
# Mistake 0: within ADP NOUN
# Mistake 1: oral ADJ NOUN
# Mistake 2: appeared VERB NOUN
# Mistake 3: require VERB NOUN
# Mistake 4: most ADJ ADV
#
# Sentence 86: Shell people did not , strictly speaking , breathe .
# Mistake 0: strictly ADV NOUN
# Mistake 1: speaking VERB NOUN
#
# Sentence 87: For their purposes , oxygen and other gases were not drawn from the surrounding atmosphere through the medium of lungs but sustained artificially by solution in their shells .
# Mistake 0: drawn VERB NOUN
# Mistake 1: surrounding VERB NOUN
# Mistake 2: sustained VERB NOUN
# Mistake 3: artificially ADV NOUN
#
# Sentence 88: After experimentation , Helva discovered that she could manipulate her diaphragmic unit to sustain tone .
# Mistake 0: After ADP NOUN
# Mistake 1: manipulate VERB NOUN
# Mistake 2: diaphragmic ADJ NOUN
# Mistake 3: sustain VERB NOUN
#
# Sentence 89: By relaxing the throat muscles and expanding the oral cavity well into the frontal sinuses , she could direct the vowel sounds into the most felicitous position for proper reproduction through her throat microphone .
# Mistake 0: By ADP NOUN
# Mistake 1: relaxing VERB NOUN
# Mistake 2: expanding VERB NOUN
# Mistake 3: oral ADJ NOUN
# Mistake 4: frontal ADJ NOUN
# Mistake 5: direct VERB NOUN
# Mistake 6: felicitous ADJ NOUN
#
# Sentence 90: She compared the results with tape recordings of modern singers and was not unpleased although her own tapes had a peculiar quality about them , not at all unharmonious , merely unique .
# Mistake 0: modern ADJ NOUN
# Mistake 1: unpleased ADJ NOUN
# Mistake 2: peculiar ADJ NOUN
# Mistake 3: all ADV PRT
# Mistake 4: unharmonious ADJ NOUN
# Mistake 5: merely ADV NOUN
#
# Sentence 91: Acquiring a repertoire from the Laboratory library was no problem to one trained to perfect recall .
# Mistake 0: Acquiring VERB NOUN
# Mistake 1: one NOUN NUM
# Mistake 2: to ADP PRT
#
# Sentence 92: She found herself able to sing any role and any song which struck her fancy .
# Mistake 0: herself PRON NOUN
# Mistake 1: sing VERB NOUN
# Mistake 2: struck VERB NOUN
# Mistake 3: her PRON DET
#
# Sentence 93: It would not have occurred to her that it was curious for a female to sing bass , baritone , tenor , alto , mezzo , soprano and coloratura as she pleased .
# Mistake 0: occurred VERB NOUN
# Mistake 1: to ADP PRT
# Mistake 2: her PRON DET
# Mistake 3: curious ADJ NOUN
# Mistake 4: to PRT ADP
# Mistake 5: sing VERB NOUN
#
# Sentence 94: It was , to Helva , only a matter of the correct reproduction and diaphragmic control required by the music attempted .
# Mistake 0: to ADP PRT
# Mistake 1: diaphragmic ADJ NOUN
# Mistake 2: attempted VERB NOUN
